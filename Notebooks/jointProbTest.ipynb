# %%
# Neural Network Analysis Demo
# This notebook demonstrates how to use the NetworkAnalyzer and WeightBinning classes

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# Add parent directory to Python path to import from sibling directories
import sys
import os
# Get the absolute path of the current notebook's directory
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
# Get the parent directory
parent_dir = os.path.dirname(notebook_dir)
# Add parent directory to path
sys.path.append(parent_dir)

from Architectures.permutation_free_architecture import PermutationFreeNet
from Architectures.standardRegArchitecture import SimpleNet
from Classes.weight_binning import WeightBinning
from Classes.network_analyzer import NetworkAnalyzer

# %%
save_dir = "/home2/coles8/Large-Scale-Design-and-Analysis-of-Neural-Networks/outputs/jointProbTest"
all_networks_dir = "/home2/coles8/savedNetworks/"

# Set the architecture, save directory, and load path
architecture = PermutationFreeNet
# architecture = SimpleNet
wb_save_dir = f"{save_dir}/binning" 
# load_path = f"{save_dir}/working_networks.pt"
# load_path = f"{all_networks_dir}/simpleNet100k.pt"
load_path = f"{all_networks_dir}/perm_free/accurateNetPhenotype.pt"

# Instantiate WeightBinning
wb = WeightBinning(architecture=architecture, save_dir=wb_save_dir, load_path=load_path, num_bins=20)
# Out:
# Number of networks loaded:
# 5600
# Loaded models
# Stored weights

# %%
# wb.analyze_distributions(
#     layer=0,
#     kl_threshold=0.001,
#     multi_peak=False,
#     peaks_per_layer=None,
#     random_state=42,
# )
# layer_weight_distributions = wb.get_layer_weight_distributions()
# print(len(layer_weight_distributions))

# %%
# For layer 0
wb.analyze_distributions(
    layer=0,
    kl_threshold=0.001,
    multi_peak=True,
    peaks_per_layer=[3, 2, 2, 2, 2]
)
# Out:
# Normalizing distributions...
# Fitting GMM models...
# WARNING: Insufficient samples for GMM at layer 0, neuron 0, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 0, neuron 2, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 0, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 1, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 1, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 2, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 3, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 3, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 4, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 5, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 1, neuron 5, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 0, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 0, input 4. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 0, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 1, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 1, input 4. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 1, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 2, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 2, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 2, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 3, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 3, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 3, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 4, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 4, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 4, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 5, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 5, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 2, neuron 5, input 4. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 0, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 0, input 4. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 0, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 1, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 1, input 4. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 1, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 2, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 2, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 2, input 5. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 3, input 0. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 3, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 3, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 4, input 1. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 4, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 4, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 5, input 2. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 5, input 3. Adding noise to create multiple samples.
# WARNING: Insufficient samples for GMM at layer 3, neuron 5, input 4. Adding noise to create multiple samples.
# Clustering GMMs with KL threshold 0.001...
# Plotting unique GMM distributions for layer 0...
# Plotting unique GMM cluster 0 at position (0, 0)
# Plotting unique GMM cluster 1 at position (0, 1)
# Plotting unique GMM cluster 2 at position (1, 0)
# Plotting unique GMM cluster 3 at position (1, 1)
# Plotting unique GMM cluster 4 at position (2, 1)
# Found 5 unique GMM distributions in layer 0
# [array([[0, 1],
#         [2, 3],
#         [1, 4]]),
#  array([[0, 1, 2],
#         [3, 1, 1],
#         [4, 5, 1],
#         [1, 6, 1],
#         [1, 7, 8],
#         [1, 1, 9]]),
#  array([[ 0,  1,  2,  3,  3,  3],
#         [ 3,  4,  5,  6,  3,  3],
#         [ 3,  3,  0,  7,  8,  3],
#         [ 3,  3,  3,  4,  9, 10],
#         [11,  3,  3,  3,  2, 12],
#         [13,  1,  3,  3,  3,  6]]),
#  array([[0, 1, 2, 3, 3, 3],
#         [3, 1, 2, 2, 3, 3],
#         [3, 3, 2, 2, 4, 3],
#         [3, 3, 3, 2, 2, 5],
#         [2, 3, 3, 3, 2, 6],
#         [2, 2, 3, 3, 3, 5]]),
#  array([[0, 1, 2, 3, 4, 5]])]

# %%
# # For layer 1
# wb.analyze_distributions(
#     layer=1,
#     kl_threshold=0.001,
#     multi_peak=True,
#     peaks_per_layer=[2, 2, 2, 2, 2]
# )

# %%
# # For layer 2
# wb.analyze_distributions(
#     layer=2,
#     kl_threshold=0.001,
#     multi_peak=True,
#     peaks_per_layer=[2, 2, 2, 2, 2]
# )

# %%
# # For layer 3
# wb.analyze_distributions(
#     layer=3,
#     kl_threshold=0.001,
#     multi_peak=True,
#     peaks_per_layer=[2, 2, 2, 2, 2]
# )

# %%
# # For layer 4
# wb.analyze_distributions(
#     layer=4,
#     kl_threshold=0.001,
#     multi_peak=True,
#     peaks_per_layer=[2, 2, 2, 2, 2]
# )

# %%
wb.plot_conditional_weight_matrix(0, (2, 1), (1, 1))
# Out:
# (<Figure size 1000x800 with 2 Axes>,
#  <Axes: title={'center': 'Conditional Distribution P(w(1, 1) | w(2, 1))'}, xlabel='Weight at position (2, 1)', ylabel='Weight at position (1, 1)'>)

# %%
wb.plot_conditional_weight_matrix(0, (0, 0), (1, 0))
# Out:
# (<Figure size 1000x800 with 2 Axes>,
#  <Axes: title={'center': 'Conditional Distribution P(w(1, 0) | w(0, 0))'}, xlabel='Weight at position (0, 0)', ylabel='Weight at position (1, 0)'>)
