# %%
# Neural Network Analysis Demo
# This notebook demonstrates how to use the NetworkAnalyzer and WeightBinning classes

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# Add parent directory to Python path to import from sibling directories
import sys
import os
# Get the absolute path of the current notebook's directory
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
# Get the parent directory
parent_dir = os.path.dirname(notebook_dir)
# Add parent directory to path
sys.path.append(parent_dir)

from Architectures.permutation_free_architecture import PermutationFreeNet
from Classes.weight_binning import WeightBinning
from Classes.network_analyzer import NetworkAnalyzer
from Classes.compare_weight_distributions import CompareWeightDistributions

# %%
save_dir = "/home2/coles8/Large-Scale-Design-and-Analysis-of-Neural-Networks/outputs/networkComparison"
all_networks_dir = "/home2/coles8/savedNetworks/"

# Set the architecture, save directory, and load path
architecture = PermutationFreeNet
wb_save_dir = f"{save_dir}/binning" 
# load_path = f"{save_dir}/working_networks.pt"
load_path_reference = f"{all_networks_dir}/perm_free/accurateNet4800.pt"
load_path_phenotype = f"{all_networks_dir}/perm_free/accurateNetPhenotype4800.pt"

# Instantiate WeightBinning
wb_reference = WeightBinning(architecture=architecture, save_dir=wb_save_dir, load_path=load_path_reference, min_weight=-2, max_weight=2, num_bins=30)
wb_phenotype = WeightBinning(architecture=architecture, save_dir=wb_save_dir, load_path=load_path_phenotype, min_weight=-2, max_weight=2, num_bins=30)
# Out:
# Number of networks loaded:
# 4800
# Loaded models
# Layer 0: Filtering 97/28800 weights (0.34%)
# Layer 1: Filtering 1844/86400 weights (2.13%)
# Layer 2: Filtering 1520/172800 weights (0.88%)
# Layer 3: Filtering 1447/172800 weights (0.84%)
# Layer 4: Filtering 1402/28800 weights (4.87%)
# Total: Filtered 6310/489600 weights (1.29%)
# Layer 0, Position (0, 0): Discarded 41 weights outside range
#   Min discarded: -2.7277631759643555, Max discarded: 2.592604875564575
#   Total weights kept: 4759
# Stored weights
# Layer 0 has 2 all-zero weights
#   Positions: [(0, 1), (2, 0)]
# Layer 1 has 9 all-zero weights
#   Positions: [(0, 1), (1, 1), (1, 2), (2, 2), (3, 0), (3, 2), (4, 0), (5, 0), (5, 1)]
# Layer 2 has 18 all-zero weights
#   Positions: [(0, 3), (0, 4), (0, 5), (1, 0), (1, 4), (1, 5), (2, 0), (2, 1), (2, 5), (3, 0), (3, 1), (3, 2), (4, 1), (4, 2), (4, 3), (5, 2), (5, 3), (5, 4)]
# Layer 3 has 18 all-zero weights
# ...

# %%
# wb.analyze_distributions(
#     layer=0,
#     kl_threshold=0.001,
#     multi_peak=False,
#     peaks_per_layer=None,
#     random_state=42,
# )
layer_weight_distributions_reference = wb_reference.get_layer_weight_distributions()
layer_weight_distributions_phenotype = wb_phenotype.get_layer_weight_distributions()
print(wb_reference.layer_weight_distributions_counts[0][0][1])
print(wb_reference.layer_weight_distributions_networks[0][0][1])

print(len(layer_weight_distributions_reference))
print(len(layer_weight_distributions_phenotype))
# Out:
# [None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None]
# [None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None]
# 5
# 5

# %%
# For layer 0
wb_reference.analyze_distributions(
    layer=0,
    kl_threshold=0.001,
    multi_peak=True,
    peaks_per_layer=[3, 2, 2, 2, 2]
)
print(wb_reference.cluster_indices[0])
# Out:
# Normalizing distributions...
# Fitting GMM models...
# Clustering GMMs with KL threshold 0.001...
# Plotting unique GMM distributions for layer 0...
# Plotting unique GMM cluster 0 at position (0, 0)
# Plotting unique GMM cluster 2 at position (1, 0)
# Plotting unique GMM cluster 3 at position (1, 1)
# Plotting unique GMM cluster 5 at position (2, 1)
# Found 4 unique GMM distributions in layer 0
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
wb_phenotype.analyze_distributions(
    layer=0,
    kl_threshold=0.001,
    multi_peak=True,
    peaks_per_layer=[3, 2, 2, 2, 2]
)
print(wb_phenotype.cluster_indices[0])
# Out:
# Normalizing distributions...
# Fitting GMM models...
# Clustering GMMs with KL threshold 0.001...
# Plotting unique GMM distributions for layer 0...
# Plotting unique GMM cluster 0 at position (0, 0)
# Plotting unique GMM cluster 2 at position (1, 0)
# Plotting unique GMM cluster 3 at position (1, 1)
# Plotting unique GMM cluster 5 at position (2, 1)
# Found 4 unique GMM distributions in layer 0
# [[0 1]
#  [2 3]
#  [4 5]]

# %% [markdown]
# reference:
# [array([[0, 1],
#         [2, 3],
#         [1, 4]]),
#  array([[0, 1, 2],
#         [3, 1, 1],
#         [4, 5, 1],
#         [1, 6, 1],
#         [1, 7, 8],
#         [1, 1, 9]]),
#  array([[ 0,  1,  2,  3,  3,  3],
#         [ 3,  4,  5,  6,  3,  3],
#         [ 3,  3,  7,  8,  9,  3],
#         [ 3,  3,  3, 10, 11, 12],
#         [13,  3,  3,  3, 14, 15],
#         [16, 10,  3,  3,  3, 17]]),
#  array([[ 0,  1,  2,  3,  3,  3],
#         [ 3,  4,  5,  6,  3,  3],
#         [ 3,  3,  7,  8,  9,  3],
#         [ 3,  3,  3,  8, 10, 11],
#         [11,  3,  3,  3, 12, 11],
#         [13,  2,  3,  3,  3, 14]]),
#  array([[0, 1, 2, 3, 4, 5]])]
#
# phenotype:
# [array([[0, 1],
#         [2, 3],
#         [1, 4]]),
#  array([[0, 1, 2],
#         [3, 1, 1],
#         [4, 5, 1],
#         [1, 6, 1],
#         [1, 7, 8],
#         [1, 1, 9]]),
#  array([[ 0,  1,  2,  3,  3,  3],
#         [ 3,  4,  5,  6,  3,  3],
#         [ 3,  3,  7,  8,  9,  3],
#         [ 3,  3,  3, 10, 11, 12],
#         [13,  3,  3,  3, 14, 15],
#         [16, 17,  3,  3,  3, 18]]),
#  array([[ 0,  1,  2,  3,  3,  3],
#         [ 3,  4,  5,  6,  3,  3],
#         [ 3,  3,  6,  7,  8,  3],
#         [ 3,  3,  3,  9,  8, 10],
#         [ 2,  3,  3,  3, 11, 12],
#         [13,  2,  3,  3,  3,  2]]),
#  array([[0, 1, 2, 3, 4, 5]])]

# %%
compare = CompareWeightDistributions(wb_reference, wb_phenotype, kl_match_threshold=0.03, use_normalized=False)
compare.compare_unique_distributions(0)
# Out:
# Using raw count distributions for comparison
# {'comparison_matrix': array([[0.00139176, 0.37927361, 0.29125359, 0.06501525],
#         [0.37411655, 0.00115836, 0.03301636, 0.44370419],
#         [0.32956591, 0.02000444, 0.00617179, 0.41964334],
#         [0.07122058, 0.44308884, 0.39359092, 0.00548301]]),
#  'ref_unique_clusters': {0: (0, 0), 2: (1, 0), 3: (1, 1), 5: (2, 1)},
#  'phen_unique_clusters': {0: (0, 0), 2: (1, 0), 3: (1, 1), 5: (2, 1)},
#  'ref_cluster_positions': {0: 0, 2: 1, 3: 2, 5: 3},
#  'phen_cluster_positions': {0: 0, 2: 1, 3: 2, 5: 3},
#  'matches': [(0, 0, 0.0013917636372957401),
#   (2, 2, 0.0011583611439340094),
#   (3, 2, 0.02000444436161819),
#   (3, 3, 0.006171790081700008),
#   (5, 5, 0.0054830114768872115)],
#  'position_mappings': {(0, 0): {'ref_cluster_id': 0,
#    'phen_cluster_id': 0,
#    'kl_divergence': 0.0013917636372957401,
#    'is_match': True},
#   (1, 1): {'ref_cluster_id': 3,
#    'phen_cluster_id': 3,
# ...

# %%
compare.compare_and_plot(
    layer=0,                    # First layer
    apply_correction=False,      # Apply multiple testing correction
    alpha=0.06,                 # Significance threshold
    top_n=10,                   # Show top 10 most significant differences
    save_dir='outputs/chi2_plots'     # Save plots to this directory
)
# Out:
# Performed chi-square comparison on 4 weight positions
# Found 2 positions with significant differences (p < 0.06)
# Plotting significant difference at position (2, 1), p-value = 2.3668e-02
# Plotting significant difference at position (1, 1), p-value = 5.1246e-02
# ({(0, 0): {'chi2_stat': 21.623071620953326,
#    'p_value': 0.8354569720367697,
#    'residuals': array([[ 1.68974972e-01,  9.44295946e-01, -6.29816631e-01,
#            -6.76065707e-01,  4.95880879e-01, -3.96495095e-01,
#             9.60906382e-02, -6.53407289e-01, -2.69315993e-01,
#             3.51945655e-01,  4.38117795e-01,  4.51308099e-01,
#            -3.35715817e-01,  2.11139093e-01,  1.45678737e+00,
#             1.68974972e-01, -1.06259266e+00,  8.08174437e-01,
#            -6.57280394e-01,  9.94002217e-05,  3.90365551e-01,
#            -2.95681130e-01,  1.64107305e-01, -1.15823866e+00,
#             8.45187755e-01, -2.03714286e-01,  1.72842391e-01,
# ...

# %%
# compare.compare_and_plot(
#     layer=1,                    # First layer
#     apply_correction=False,      # Apply multiple testing correction
#     alpha=0.1,                 # Significance threshold
#     top_n=10,                   # Show top 10 most significant differences
#     save_dir='outputs/chi2_plots'     # Save plots to this directory
# )

# %%
# compare.compare_and_plot(
#     layer=1,                    # First layer
#     apply_correction=False,      # Apply multiple testing correction
#     alpha=0.9,                 # Significance threshold
#     top_n=10,                   # Show top 10 most significant differences
#     save_dir='outputs/chi2_plots'     # Save plots to this directory
# )

# %%
# Run the driver function
logistic_results, figs, summary = compare.driver_logistic_regression_for_matching(0, save_dir="outputs/log_reg", apply_correction=False)
print(summary)
# Out:
# Found 4 matching weight positions in layer 0.
# Saved significance plot for weight position (0, 0) to outputs/log_reg/significance_hist_layer0_pos0_0.png
# Saved Manhattan plot for weight position (0, 0) to outputs/log_reg/logistic_regression_layer0_pos0_0.png
# Saved significance plot for weight position (1, 0) to outputs/log_reg/significance_hist_layer0_pos1_0.png
# Saved Manhattan plot for weight position (1, 0) to outputs/log_reg/logistic_regression_layer0_pos1_0.png
# Saved significance plot for weight position (1, 1) to outputs/log_reg/significance_hist_layer0_pos1_1.png
# Saved Manhattan plot for weight position (1, 1) to outputs/log_reg/logistic_regression_layer0_pos1_1.png
# Saved significance plot for weight position (2, 1) to outputs/log_reg/significance_hist_layer0_pos2_1.png
# Saved Manhattan plot for weight position (2, 1) to outputs/log_reg/logistic_regression_layer0_pos2_1.png
# ===== LOGISTIC REGRESSION SIGNIFICANCE SUMMARY FOR LAYER 0 =====
#
# ...

# %% [raw]
# logistic_results, figs, summary = compare.driver_logistic_regression_for_matching(0, save_dir="outputs/log_reg", apply_correction=True)
# print(summary)
